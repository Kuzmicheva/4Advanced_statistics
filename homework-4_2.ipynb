# %% [markdown]
# # Домашняя работа №4

# %% [markdown]
# # Виды распределений

# %% [markdown]
# Загрузить таблицу и построить график распределений. Найти нормальное распределение.

# %%
import numpy as np
from scipy.stats import t
from scipy.stats import norm
import matplotlib.pyplot as plt
from scipy import stats
import pandas as pd
import io
import requests
import seaborn as sns
from sklearn.metrics import mean_squared_error, mean_absolute_error
import warnings
warnings.filterwarnings("ignore")

# %matplotlib inline

# %% [markdown]
# Таблица цен на дома в Бостоне

# %% [markdown]
# Основные значения:
#
# * CRIM: This is the per capita crime rate by town
# * ZN: This is the proportion of residential land zoned for lots larger than 25,000 sq.ft.
# * INDUS: This is the proportion of non-retail business acres per town.
# * CHAS: This is the Charles River dummy variable (this is equal to 1 if tract bounds river; 0 otherwise)
# * NOX: This is the nitric oxides concentration (parts per 10 million)
# * RM: This is the average number of rooms per dwelling
# * AGE: This is the proportion of owner-occupied units built prior to 1940
# * DIS: This is the weighted distances to five Boston employment centers
# * RAD: This is the index of accessibility to radial highways
# * TAX: This is the full-value property-tax rate per 10,000 dollars
# * PTRATIO: This is the pupil-teacher ratio by town
# * B: This is calculated as 1000(Bk — 0.63)², where Bk is the proportion of people of African American descent by town
# * LSTAT: This is the percentage lower status of the population
# * MEDV: This is the median value of owner-occupied homes in 1000 dollars

# %%
import ssl
# следующая строчка подключает сертификат для защищенного соединения
ssl._create_default_https_context = ssl._create_unverified_context
url='http://yustiks.ru/dataset/housing.csv'
names = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO', 'B', 'LSTAT', 'MEDV']
data=pd.read_csv(url,  delim_whitespace=True, names=names)
data.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296.0
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242.0
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242.0
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222.0
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %% [markdown]
# Нарисовать частотные графики для всех значений. Можете ли вы найти следующие распределения в данных графиках?
#
#
# 1.   Нормальное
# 2.   Равномерное
# 3.   Биноминальное
# 4.   Бернулли
# 5.   Геометрическое
# 6.   Логнормальное

# %%
# ПРЕСТУПНОСТЬ: Это уровень преступности на душу населения по городам.
# ЗН: Это доля земли под жилую застройку, предназначенная для участков площадью более 25 000 кв. Футов.
# ПРОМЫШЛЕННОСТЬ: Это доля акров, не относящихся к розничной торговле, на город.
# CHAS: это фиктивная переменная реки Чарльз (она равна 1, если участок ограничивает реку; 0 в противном случае)
# NOX: это концентрация оксидов азота (частей на 10 миллионов).
# РМ: Это среднее количество комнат в доме.
# ВОЗРАСТ: Это доля занятых владельцами единиц, построенных до 1940 года.
# DIS: Это взвешенные расстояния до пяти бостонских центров занятости.
# РАД: это индекс доступности радиальных магистралей.
# НАЛОГ: Это полная ставка налога на имущество за 10 000 долларов.
# ПРАТИО: соотношение учеников и учителей по городам.
# B: рассчитывается как 1000 (Bk - 0,63) ², где Bk - это доля лиц афроамериканского происхождения по городам.
# LSTAT: это процентный более низкий статус населения.
# МЭДВ: Это средняя стоимость частных домов в 1000 долларов.

# %%
data_CRIM = data['CRIM']
sns.distplot(data_CRIM)
plt.title('Частотный график "Уровень преступности на душу населения по городам"')
plt.show()

# %% [markdown]
# ### Геометрическое

# %%
sns.distplot(data['ZN'])
plt.title('Частотный график "Доля земли под жилую застройку"')
plt.show()

# %% [markdown]
# ### Геометрическое

# %%
sns.distplot(data['INDUS'])
plt.title('Частотный график "Промышленность"')
plt.show()

# %% [markdown]
# ### ?

# %%
sns.distplot(data['CHAS'])
plt.title('Частотный график CHAS')
plt.show()

# %% [markdown]
# ### Бернулли

# %%
sns.distplot(data['NOX'])
plt.title('Частотный график "Доля земли под жилую застройку"')
plt.show()

# %% [markdown]
# ### Биноминальное???

# %%
sns.distplot(data['RM'])
plt.title('Частотный график NOX')
plt.show()

# %% [markdown]
# ### Нормальное

# %%
sns.distplot(data['AGE'])
plt.title('Частотный график "ВОЗРАСТ"')
plt.show()

# %% [markdown]
# ### ?

# %%
sns.distplot(data['DIS'])
plt.title('Частотный график DIS')
plt.show()

# %% [markdown]
# ### Геометрическое

# %%
sns.distplot(data['RAD'])
plt.title('Частотный график RAD')
plt.show()

# %% [markdown]
# ### Бернулли

# %%
sns.distplot(data['TAX'])
plt.title('Частотный график Налоги')
plt.show()

# %% [markdown]
# ### Бернулли

# %% [markdown]
# sns.distplot(data['PTRATIO'])
# plt.title('Частотный график "Доля земли под жилую застройку"')
# plt.show()

# %%
sns.distplot(data['B'])
plt.title('Частотный график PTRATIO')
plt.show()

# %% [markdown]
# ## Обратное геометрическое?

# %%
sns.distplot(data['LSTAT'])
plt.title('Частотный график LSTAT')
plt.show()

# %% [markdown]
# ### Логнормальное

# %%
sns.distplot(data['MEDV'])
plt.title('Частотный график "Средняя стоимость частных домов"')
plt.show()

# %% [markdown]
# ### Биноминальное

# %% [markdown]
# Построить матрицу корреляций для данной таблицы и выбрать максимально коррелирующий атрибут (несколько атрибутов) с ценой на дома (MEDV атрибут).

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
# gcf() - получение текущей фигуры
fig=plt.gcf()
# set_size_inches() - установить размер фигуры
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# #### Количество комнат в доме(RM) максимально коррелирующий атрибут с ценой на дома (MEDV) (0,7)

# %%
plt.scatter(data['MEDV'], data['RM'])
plt.xlabel('Цена (тыс.долл.)')
plt.ylabel('Кол-во комнат')
# Out:
# Text(0, 0.5, 'Кол-во комнат')

# %% [markdown]
# Написать **линейную регрессию** на два атрибута. Допустим, мы хотим предсказать цену дома (MEDV) в Бостоне, зная что цена на дом имеет линейную зависимость с атрибутом LSTAT.

# %% [markdown]
# 1.   Разделить данные на 80% тренировочных, 20% тестовых
# 2.   Составить модель линейной регрессии
# 3.   Посчитать ошибку модели на тестовых данных
# 4.   Сделать точечный график данных и полученной прямой линейной регрессии

# %%
medv = data['MEDV']
rm = data['RM']

medv_ = np.array(medv).reshape(-1,1)
rm_ = np.array(rm).reshape(-1,1)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    medv_, #x
    rm_, #y
    test_size = 0.2
)

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predicted_y = model.predict(X_test)

# %%
print('Среднеквадратичная ошибка: ', mean_squared_error(predicted_y, y_test))
print('Абсолютная ошибка: ', mean_absolute_error(predicted_y, y_test))
# Out:
# Среднеквадратичная ошибка:  0.30471252436123714
# Абсолютная ошибка:  0.35689538552546657

# %% [markdown]
# #### Ошибки модели стремятся к нулю!

# %%
# Построим график линейной регресии
plt.xlabel('Цена (тыс.долл.)')
plt.ylabel('Кол-во комнат')
plt.title('Линейная регрессия от одной переменной')
# Построим прямую для регрессии
# Создадим 100 точек для предсказаний
x = np.linspace(0, 60, 100)
# Посчитаем предсказанные значения
# y = kx + b
# k = model.coef_
# b = model.intercept_
y = model.coef_*x + model.intercept_
y = np.transpose(y)
plt.plot(x,y)
plt.plot(X_train, y_train, 'r.')
plt.plot(X_test, y_test, 'g.')
plt.xlim(0,60)
plt.ylim(0,9)
plt.legend(['Прямая линейной регрессии', 'Тренировочные данные', 'Тестовые данные'])
plt.show()

# %% [markdown]
# Загрузить таблицу Happiness report. Посчитать матрицу ковариаций попарно.

# %%
url="http://yustiks.ru/dataset/world-happiness-report-2019.csv"
data=pd.read_csv(url)
data.head()
# Out:
#   Country (region)  Ladder  SD of Ladder  Positive affect  Negative affect  \
# 0          Finland       1             4             41.0             10.0
# 1          Denmark       2            13             24.0             26.0
# 2           Norway       3             8             16.0             29.0
# 3          Iceland       4             9              3.0              3.0
# 4      Netherlands       5             1             12.0             25.0
#
#    Social support  Freedom  Corruption  Generosity  Log of GDP\nper capita  \
# 0             2.0      5.0         4.0        47.0                    22.0
# 1             4.0      6.0         3.0        22.0                    14.0
# 2             3.0      3.0         8.0        11.0                     7.0
# 3             1.0      7.0        45.0         3.0                    15.0
# 4            15.0     19.0        12.0         7.0                    12.0
#
#    Healthy life\nexpectancy
# 0                      27.0
# ...

# %% [markdown]
# Сколько в данной таблице отсутствующих значений? Написать ответ. Если есть отсутствующие значения в выборке country, убрать (drop).

# %% [markdown]
# Сколько стран в выборке? Написать ответ.

# %% [markdown]
# Построить матрицу корреляций для таблицы. Какие можно сделать выводы?

# %%
# Количество отсутсвующих значений
data.isnull().sum(axis = 0)
# Out:
# Country (region)            0
# Ladder                      0
# SD of Ladder                0
# Positive affect             1
# Negative affect             1
# Social support              1
# Freedom                     1
# Corruption                  8
# Generosity                  1
# Log of GDP\nper capita      4
# Healthy life\nexpectancy    6
# dtype: int64

# %% [markdown]
# #### В выборке Country нет отстутствующих значений

# %%
print('Количество стран в выборке: ', data['Country (region)'].nunique())
# Out:
# Количество стран в выборке:  156

# %%
sns.heatmap(data.corr(),annot=True,cmap='RdYlGn',linewidths=0.2) #data.corr()-->матрица корреляций
fig=plt.gcf()
fig.set_size_inches(12,12)
plt.show()

# %% [markdown]
# ВВП на душу населения(Log of GDP) + Ожидаемая продолжительность здоровой жизни(Healthy life expectancy) 0.85
# *Чем больше ВВП на человека в стране, тем больше ожидания продолжительности жизни*
#
#
#                                   + Показатель удовлетворенности жизнью(Ladder) 0.81
# *Прямая, но оппосредованная зависимость*
#
#
#                                   + Социальная поддержка (Social support) 0.77
# *Прямая зависимость кол-во денег и социальных проектов*
#
#
#
# Социальная поддержка (Social support) + Показатель удовлетворенности жизнью(Ladder) 0.82
# *Прямая зависимость*
#
#
# Показатель удовлетворенности жизнью(Ladder) + Ожидаемая продолжительность здоровой жизни(Healthy life expectancy) 0.82
# *Тут наверно, оппосредованная зависимость*
#
#
# Социальная поддержка (Social support) + Ожидаемая продолжительность здоровой жизни(Healthy life expectancy) 0.74
# *Прямая зависимость, чувство поддержки*
#
#
# Степень свободы(Freedom) + Мера положительных эмоций (Positive affect)  0.68
# *Прямая зависимость кол-во свобод влиеет на положительные эмоции*

# %% [markdown]
# # Дискретное распределение случайной величины

# %% [markdown]
# Напишите код для моделирования 10 подбрасываний игрального кубика. Начертите диаграму histogram. Какое это распределение?

# %%
import random

# %%
plt.hist(np.random.randint(1, 6, 10))
plt.show()

# %% [markdown]
# ##### Распределение стремится к равномерному

# %% [markdown]
# Смоделируйте 1000 раз сумму по 100 подбрасываний. Начертите диаграму histogram. Почему график изменился? Почему можно применить центральную предельную теорему?

# %%
number_of_sums = 1000
number_of_randoms = 100
X1 = np.zeros([number_of_sums])
for i in range(number_of_sums):
    # суммируем все элементы равномерных выборок
    X1[i] = np.sum(np.random.randint(1, 6, 100))/number_of_randoms
plt.hist(X1, 50)
plt.xlabel('X values')
plt.ylabel('Number of elements in each X')
plt.show()

# %% [markdown]
# ##### Суммы элементов элементов выборок стремится к нормальному распределению.
# ##### По центральной предельной теореме сумма большого количества независимых случайных величин имеет распределение близкое к нормальному.
# ##### График иллюструет это
